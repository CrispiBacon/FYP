# %% [markdown]
# # Preprocessing

# %%
import pandas as pd

df = pd.read_csv(r'..\4. Data Understanding\merged_data.csv', header=0)

df.head()
# Out:
#                                                 Text  Target  \
# 0  Mommy said not to talk to strangers..but she's...     1.0
# 1  1.I was immune to getting hurt/killed/infected...     1.0
# 2  I mean terrorist attacks happen all the time. ...     1.0
# 3  As a god, it would be my responsibility not to...     1.0
# 4  I am going to grab a knife and shove it in the...     1.0
#
#               Source
# 0  SchooshooterTexts
# 1  SchooshooterTexts
# 2  SchooshooterTexts
# 3  SchooshooterTexts
# 4  SchooshooterTexts

# %%
import pandas as pd
import spacy
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")


# NLP preprocessing function
def preprocess(text):
    doc = nlp(text.lower())
    tokens = [
        token.lemma_ for token in doc 
        if token.is_alpha and not token.is_stop
    ]
    return " ".join(tokens)

# Apply preprocessing
df['clean_text'] = df['Text'].apply(preprocess)

# TF-IDF vectorization
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['clean_text'])
y = df['Target']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train classifier
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7746062992125984
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.36      0.52       239
#          1.0       0.74      0.98      0.84       638
#          2.0       0.95      0.55      0.70       139
#
#     accuracy                           0.77      1016
#    macro avg       0.86      0.63      0.69      1016
# weighted avg       0.81      0.77      0.75      1016

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import torch
from torch.utils.data import DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import get_scheduler
from datasets import Dataset
from tqdm import tqdm

# 1. Encode the labels
label_encoder = LabelEncoder()
df["label_encoded"] = label_encoder.fit_transform(df["Target"])

# 2. Split data
train_texts, test_texts, train_labels, test_labels = train_test_split(
    df["Text"], df["label_encoded"], test_size=0.2, stratify=df["label_encoded"], random_state=42
)

# 3. Tokenization
tokenizer = BertTokenizer.from_pretrained('distilbert-base-uncased')
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(list(test_texts), truncation=True, padding=True, max_length=128)

# 4. Create custom dataset
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        return {
            key: torch.tensor(val[idx])
            for key, val in self.encodings.items()
        } | {'labels': torch.tensor(self.labels[idx])}

    def __len__(self):
        return len(self.labels)

train_dataset = CustomDataset(train_encodings, list(train_labels))
test_dataset = CustomDataset(test_encodings, list(test_labels))

# 5. Model setup
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 6. Training setup
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8)

optimizer = AdamW(model.parameters(), lr=5e-5)
num_training_steps = len(train_loader) * 3  # for 3 epochs
lr_scheduler = get_scheduler("linear", optimizer=optimizer,
                             num_warmup_steps=0,
                             num_training_steps=num_training_steps)

# 7. Train loop
model.train()
for epoch in range(3):
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}")
    for batch in loop:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        loop.set_postfix(loss=loss.item())

# 8. Evaluation
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for batch in test_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        preds = torch.argmax(outputs.logits, dim=-1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch['labels'].cpu().numpy())

# 9. Print results
print("Classification Report:\n")
print(classification_report(all_labels, all_preds, target_names=label_encoder.classes_))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Program Files\Python311\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1:   0%|          | 0/170 [00:00<?, ?it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import re
import emoji
import nltk
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, words
from nltk.stem import WordNetLemmatizer
from autocorrect import Speller
from bs4 import BeautifulSoup

# Download necessary NLTK data
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("words")

# Initialize tools
spell = Speller(lang="en")  # Autocorrect spelling
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
english_vocab = set(words.words())

def preprocess_text(text):
    if not isinstance(text, str):
        return ""

    # Text Normalization
    text = text.lower()  # Convert to lowercase
    text = contractions.fix(text)  # Expand contractions ("can't" → "cannot")
    text = re.sub(r"\s+", " ", text).strip()  # Remove excessive whitespace

    # Remove unwanted cahracters
    text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9\s#@]", "", text)  # Keep alphanumeric, hashtags, mentions

    # 3️Handle URLS, hashtags, mentions
    text = re.sub(r"http\S+|www\S+", "", text)  # Remove URLs
    text = re.sub(r"@\w+", "USER", text)  # Replace @mentions with "USER"
    text = re.sub(r"#(\w+)", lambda m: " ".join(re.findall(r"[A-Z]?[a-z]+|\d+", m.group(1))), text)  # Split hashtags

    # Handle emoji
    text = emoji.demojize(text, delimiters=(" ", " "))  
    text = re.sub(r":\S+:", lambda m: m.group(0).replace("_", " "), text)  

    # Tokenization and remove stop word
    words_list = word_tokenize(text)  # Tokenize text
    words_list = [word for word in words_list if word not in stop_words]  # Remove stopwords

    #autocorrect
    words_list = [spell(word) if word not in english_vocab else word for word in words_list]

    # Lemmatization
    words_list = [lemmatizer.lemmatize(word) for word in words_list]

    return " ".join(words_list)  # Convert list back to string

df["Text"] = df["Text"].apply(preprocess_text)

pd.set_option('display.max_rows', None)  # Show all rows
print(df)  # Display the full DataFrame
pd.reset_option('display.max_rows')  # Reset to default after viewing
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
#                                                    Text  Target  \
# 0     mommy said talk strangersbut drunk time listen...     1.0
# 1     1i immune getting hurtkilledinfected std 2i 43...     1.0
# 2     mean terrorist attack happen time sure thousan...     1.0
# 3     god would responsibility destroy universal bal...     1.0
# 4     going grab knife shove neck mother drag dead b...     1.0
# 5     rape hot love sister strangle hair sneaking pa...     1.0
# 6                         iwillneverletyouforgetaboutme     1.0
# 7     rule 11 nice nerd chance end working one start...     1.0
# 8     2005 age 9 playing sm64ds lost level went age ...     1.0
# 9     look guy smoked entire 500 worth bag og push h...     1.0
# 10    play wow turned brother basement dweller weed ...     1.0
# 11    support interesting people hope internet famou...     1.0
# 12    shortest describe troll troll basically young ...     1.0
# 13    would kill tide method may offend many would s...     1.0
# 14                                  jack gun shoot head     2.0
# 15    every personality disorder test take usually e...     1.0
# 16    hey eldigato short psychopath dedicated art de...     1.0
# 17      would cut many vein neck could avoiding jugular     1.0
# 18    guilty pleasure probably dmy ok since amazingl...     1.0
# 19    dream job would involve synthesizing pure lsd ...     1.0
# 20      living basement pretty soon finished moving bro     1.0
# 21    played game marijuana lsd saliva room honestly...     1.0
# 22    internet went people would go psycho kill each...     1.0
# 23    would go back time stop lot school shooting co...     1.0
# 24    dropping high school order study ged book sci ...     1.0
# 25    14 year old boy people say nerd cool nerd geek...     1.0
# 26    got suspended school week april wearing black ...     1.0
# 27    july 26th 2012 dream went bizarre dimension bl...     1.0
# 28        psychiatrist told need look bright side thing     1.0
# 29    30 global population capable control anyone 30...     1.0
# 30    major depression inability feel joy intense le...     1.0
# 31    autism bite infect autism way cure stop playin...     1.0
# 32      top 3 shit redneck school really accomplishment     1.0
# 33                  stuff want birthday 30 arb sandwich     1.0
# 34    ak m164 least ak kill shoot jam need special c...     1.0
# 35                    child soldier cool wish could one     1.0
# 36    think college system american society need mas...     1.0
# 37    believe 8 whole year since 2007 go well either...     1.0
# 38    massive amount american depressed lot reason l...     1.0
# 39    god world friend shift thing say help people c...     1.0
# 40    woman allowed enter military government allowe...     1.0
# 41    artist like elliot roger adam lanza1 pretty en...     1.0
# 42    girl ask treated preferentially say want princ...     1.0
# 43    ready alien contact following goal able reache...     1.0
# 44    need ww3 already way specie survive kick natur...     1.0
# 45    mass murder purity cleansing corrupt degenerat...     1.0
# 46    sex unmarried man woman think saving whatever ...     1.0
# 47    tattoo piercing selfharm anything permanently ...     1.0
# 48    woman say want intelligent friendly supportive...     1.0
# 49        hand hand basis combat fool trust life weapon     1.0
# 50    extremism bad feminism authoritarian letting g...     1.0
# 51                         kill make world better place     1.0
# 52    oh school shooting every 2 day school hostile ...     1.0
# 53          already lived texas namely abilene 20002002     1.0
# 54    woman always easy u men emotion sport killing ...     1.0
# 55    gay marriage want experience soul crushing pai...     1.0
# 56    mid 2014 wow going nostalgia frenzy scanning p...     1.0
# 57    5 came uk bro played hell out psx n64 game got...     1.0
# 58    sometimes get high jack 10 time day also high ...     1.0
# 59    stuck rural redneck town people abortion usual...     1.0
# 60    must excellent eachother best assume life make...     1.0
# 61    hitler got accepted art school manipulated jew...     1.0
# 62    want lame anything probably come town flora vi...     1.0
# 63    well irl 13th birthday back been good friend p...     1.0
# 64    inflation cranked difficulty level irl game lo...     1.0
# 65    well generation z late 90s10s birth grew devel...     1.0
# 66    cut many minor artery cause extensive bleeding...     1.0
# 67    cannibal holocaust batch early 80 movie italia...     1.0
# 68                join military waste time life anyways     1.0
# 69    believe lot people want join military feel pro...     1.0
# 70    man omnipotent nothing impossible seemed like ...     1.0
# 71    used anorexia 2010 started getting high time a...     1.0
# 72    reminds back middle school back 2006 remember ...     1.0
# 73    immediately leaving king town cutting contact ...     1.0
# 74    k6 sandy hook 78 russell middle school 912 col...     1.0
# 75    pick school back 1999 incident c like 5 someth...     1.0
# 76    think marc levine right along let feminist get...     1.0
# 77    anyone remember sitcom93 going go burn school ...     1.0
# 78    every notable figure get death threat get one ...     1.0
# 79       smoke weed fuck nun rob liquor store shoot div     1.0
# 80    another documentary archive definitely check r...     1.0
# 81    access gun hateangermental illness reason fame...     1.0
# 82    might want admit 2 hacker style event pissed d...     1.0
# 83    went school shooter namely dylan klebold5 cap ...     1.0
# 84    go day without backing get severe depression m...     1.0
# 85    reminds jeff wise believe almost 10 year since...     1.0
# 86    really sad bloke went dad committing suicide m...     1.0
# 87    time come november 18th first post site 8 year...     1.0
# 88    well may taken 13 year finally finished tower ...     1.0
# 89    first day anything inexperienced anxious nervo...     1.0
# 90    make sure use gun aim brain stem use large cal...     1.0
# 91    though ending andy adult college giving last p...     1.0
# 92    found internet user talking depression talking...     1.0
# 93    3 worked mcdonalds age 15 lol hell made thousa...     1.0
# 94    dad put 6 ft use inheritance move hell heart s...     1.0
# 95    thing remotely interested right evolution geol...     1.0
# 96    maybe columbine killer cho jeff wise adam lanz...     1.0
# 97    also living scrapmetal weed year done anything...     1.0
# 98    grandpa quiet bass killed 30 damn worker one p...     1.0
# 99    recommend old 1970s movie called man friday al...     1.0
# 100   adam lanza also pedophile gay obsessed pedobea...     1.0
# 101   yeah school day 5050 paradise absolute hell ki...     1.0
# 102                                         kill liking     1.0
# 103   least lost vcard age 16 way ahead curve compar...     1.0
# 104   well southwest atheist shit state new mexico a...     1.0
# 105   photography gunsbows hunting backing weed stum...     1.0
# 106   get real like 99 sol shooter suburban white bo...     1.0
# 107   get real like 99 sol shooter suburban white bo...     1.0
# 108   could go back time would kill eric harris12 co...     1.0
# 109   always used wake middle night deal sleep paral...     1.0
# 110     know hate mankindkill everythingkill everything     1.0
# 111   sorry life shift childhood mostly void friends...     1.0
# 112   oh government spy everything online indefinite...     1.0
# 113                                    lol suicide cool     1.0
# 114   would mass murderer highest degree trying kill...     1.0
# 115   participating internet diving sewer sludge goa...     1.0
# 116   30 minute live get high run around town gun pe...     1.0
# 117   kid school always bullied made life hell hated...     2.0
# 118                                wake 58 pm sleep 511     1.0
# 119   saw toilet like 10 pound worth shit toilet sea...     1.0
# 120   well neet extremely republican redneck rural w...     1.0
# 121   everyone black cap stand bullied u sock last 4...     1.0
# 122   take instance lived town 30 mile south albuqer...     1.0
# 123   1 love winter snow even though desert dump nev...     1.0
# 124     life pretty bad redneck mormon make mad way sad     1.0
# 125   cut soda eventually cut drink calorie diet los...     1.0
# 126   yeah unfortunately many cop follow blue code s...     1.0
# 127   would love go around world studying paranormal...     1.0
# 128   one fight back 4th grade jock douchebags range...     1.0
# 129       57 bro know hitler 58 look managed accomplish     1.0
# 130   backup yt fell back mrapophis got banned 2013 ...     1.0
# 131   save 600 buy 250 50 cal lever rifle walmart bu...     1.0
# 132   graffiti drawing satanic stuff around scare id...     1.0
# 133                       painful rusty nail sandy hook     1.0
# 134   someone make jeff weiss school release march 2...     1.0
# 135   minnesota murder first wise kid 10 year ago re...     1.0
# 136                                      mary jane need     1.0
# 137   always shock realize fast time flying long sur...     1.0
# 138   soul demon exist even know regret still around...     1.0
# 139   christmas gift 50 steam card 50 subway card 50...     1.0
# 140   stay school brush teeth make friend enjoy life...     1.0
# 141   hant mentioned going comic master against the ...     2.0
# 142                    year sucked going get much worse     1.0
# 143   good luck finding real woman nowadays sucked g...     1.0
# 144   school year except one living hell 2x worse er...     1.0
# 145   homicide indeed happened crackcocaine epidemic...     1.0
# 146   strongly suggest using 22 lobbyist beginner ob...     1.0
# 147   starbucks absolute garbage anyways probably pa...     1.0
# 148   homicidal criminal would love death penalty pu...     1.0
# 149   life ruined shithead dad beat mom abruptly for...     1.0
# 150   specialized moved town 2005 divorce dad really...     1.0
# 151   response specialized posted january 9th 2015 g...     1.0
# 152   profile name digit come know agent luz male ob...     1.0
# 153   finally justice served state recall new mexico...     1.0
# 154   stuck state 10 year prior living happy life gr...     1.0
# 155   yet keep getting worse worse shift childhood w...     1.0
# 156   playing nothing cso 10 hour day decided finall...     1.0
# 157   nerd anymore unfortunately ever since moved so...     1.0
# 158   grew been year kid got progressively worse tow...     1.0
# 159   helped make bullet head nra muhammad sex simul...     1.0
# 160   truth woman like say apple apple need nurtured...     1.0
# 161                                evil plan classified     1.0
# 162   suicide scary man mean even 12 gauge shotgun s...     1.0
# 163   wish could offer 2010 literally getting worse ...     1.0
# 164   fucking lazy read thread would rather get arab...     1.0
# 165   may 21st 2015 10 whole year since wise went ch...     1.0
# 166   listen antidepressant still risky experimental...     1.0
# 167   giving lot rosy retrospection time passable li...     1.0
# 168   mentally ill drug coming guy spent 2010 2013 h...     1.0
# 169   cat called piggy took neighbor across street g...     1.0
# 170   back breaking teeth chipping nowhere pay healt...     1.0
# 171   kill people become eternally world famous othe...     1.0
# 172   like know mrrepzion mentally ill got moderate ...     1.0
# 173   neet neet young person education employment tr...     1.0
# 174   white collar bullshit stupid as office job get...     1.0
# 175   lived south albuqerque town 80 hispanic u whit...     1.0
# 176   hero take away miss know honor day hero take s...     1.0
# 177   prostitution legal school shooting would happe...     1.0
# 178   hey sociopathic mass murder maniac shithole mi...     1.0
# 179   fuck get gotham find work dead end town 3 yr s...     1.0
# 180   violent medium usually prevents real life viol...     1.0
# 181   thanks decent unbiased post actually contribut...     1.0
# 182   want fuck 14 yr old girl as tried would killed...     1.0
# 183   today poetry wasted two decade life playing vi...     1.0
# 184   must secure existence newgrounds nger future a...     1.0
# 185   live new mexico constant race war white trash ...     1.0
# 186   bushfire 45 acp 762x39 firearm point blank ran...     1.0
# 187                   diversity foreword white genocide     1.0
# 188   kid sandy hook armed cute little flintlock ada...     1.0
# 189   enjoy nsa watchlist keep mind jew infested con...     1.0
# 190         lucky dentist suck lucky afford dental care     1.0
# 191   high school joke smoke weed yore jonas hill gi...     1.0
# 192                                    natural selector     1.0
# 193   generally african strongest race sociallyintel...     1.0
# 194   studying extremely difficult lot people even a...     1.0
# 195   backed bus comp lab 7th grade never got caught...     1.0
# 196   natural selection wrath killer humanity operat...     1.0
# 197          getting sucked high utc best feeling world     1.0
# 198   satan cool punished evil maintains justice god...     1.0
# 199   current woodworking current musiceminem since ...     1.0
# 200   usually safe place shoot would floor stone fir...     1.0
# 201   current mood aggravated edit wrote still effec...     1.0
# 202   let add fact day teaspoon applesauce eat 5 cup...     1.0
# 203   serial killer mass murderer aspect excellent e...     1.0
# 204   fuck police also protiv suicide hotline job de...     1.0
# 205   fuck police also protiv suicide hotline job de...     1.0
# 206   82 school shooter bullied presume similar numb...     1.0
# 207   columbine one reported story 90 opened pandora...     1.0
# 208   barely 20 lot contact mostly online high schoo...     1.0
# 209   hitler nothing wrong hitler right along bit fi...     1.0
# 210   suggest get good quality weed go jack take tra...     1.0
# 211   since last entry today cover following subject...     1.0
# 212   little brand like horn flesh born bone leaf sc...     1.0
# 213   need get real america gun need stop evil littl...     1.0
# 214   buy gun 50 minute drive rez present 150 get block     1.0
# 215        living desert suck dumb sock smoke rock fuck     1.0
# 216   current locationliberty city current mooddepre...     1.0
# 217   current mooddrowsy current musicclever stuff a...     1.0
# 218                                make popular kid pay     1.0
# 219   0507 q1 q2 07 rock bottom afterwards first tim...     1.0
# 220              find cheap assault rifle mass shooting     1.0
# 221   around two month since last entry usual time f...     1.0
# 222   month since last entry save 3 day currently co...     1.0
# 223                                exterminate innocent     1.0
# 224   seriously need kill retard rich baby boomer du...     1.0
# 225                                      cold dead hand     1.0
# 226                              woman treated like dog     1.0
# 227                  woman shore locked cage like champ     1.0
# 228                         woman belong realm politics     1.0
# 229   get back kitchen bitch fix lt sandwich knock t...     1.0
# 230                           school shooter u get laid     1.0
# 231   columbine opened floodgate pandora box amount ...     1.0
# 232   school shooter big chunk mass shooter cite dir...     1.0
# 233   violence answer self defense retard murdering ...     1.0
# 234   school shooter never kill people actually bull...     1.0
# 235   rebel rebel yell raise hell gon let know stomp...     1.0
# 236                       suicide pill mass murder pill     1.0
# 237                                                 luz     1.0
# 238                            protiv totalitarian moon     1.0
# 239   vast majority like 86 school shooter bullied o...     1.0
# 240   bullying isolation alienation lower life span ...     1.0
# 241   relatively lax gun law automatically result ma...     1.0
# 242   school fucking nightmare equivalent prison eve...     1.0
# 243   mass shooter school shooter given one point be...     1.0
# 244   would tld sensible method reducing amount scho...     1.0
# 245   1 actually something bullying turn school 1984...     1.0
# 246   hard moon usually teacher went way cover prote...     1.0
# 247   2 stop making mass murderer fucking celebrity ...     1.0
# 248   3 reform expand mental healthcare coverage man...     1.0
# 249                                         4 excellent     1.0
# 250   however human nature persecute different sheep...     1.0
# 251           human nature glorify violence mass killer     1.0
# 252   humanity primitive chaotic violent universe cr...     1.0
# 253   bullied kid gun access medium giving mass shoo...     1.0
# 254   address bullying keep gun away troubled kid st...     1.0
# 255                           3 word people fuck police     1.0
# 256   chris kyle mass murderer far hero another psyc...     1.0
# 257   make america great take x move variable x negr...     1.0
# 258   piss white boy good idea minority 30 million w...     1.0
# 259                                    life suck age 12     1.0
# 260   liberal cancer republican cancer neo nazi canc...     1.0
# 261   adam shot school mainly 1 strong obsession chi...     1.0
# 262         give little kid full auto a defend nowadays     1.0
# 263   worship hitler socialist ideology usually fade...     1.0
# 264   leader alt right directly connected jew way ri...     1.0
# 265   beta tag ball enough least mass murder people ...     1.0
# 266                             slide stock still legal     1.0
# 267   really feel kind embarrassed saying got ride h...     1.0
# 268   supposed function world wherever go see degene...     1.0
# 269                          long conduct mass shooting     1.0
# 270   really power first foremost task annihilation ...     1.0
# 271   remember kid plan killing people edgelords pub...     1.0
# 272                                         praise alla     1.0
# 273             thing go according plan today would die     2.0
# 274   wait school bus detected head foot disguised s...     2.0
# 275                     work suck school suck life suck     1.0
# 276                                           want shit     1.0
# 277   fuck state really bad think insane actually ra...     1.0
# 278                                                 die     1.0
# 279   hate like equality tolerance human right polit...     1.0
# 280   human race betrayed ancestor future generation...     1.0
# 281   yesterday came back night operation unfortunat...     1.0
# 282   even though seems unimportant anything else 1 ...     1.0
# 283   decided leave alone know really worth know end...     1.0
# 284   unfortunately last week realize former best fr...     1.0
# 285   yeah dog somewhat better serious wound happene...     1.0
# 286   found german heard attacked dog walk got injur...     2.0
# 287   unfortunately last day even week realize wrong...     1.0
# 288   tomorrow 24th tuesday happen nothing hate hate...     1.0
# 551                                        gg ripschool     1.0
# 552   gun shit ill probably grab hand gun buy rifle ...     1.0
# 553                 seen dad type fucking gun safe code     1.0
# 554                      way need help with bomb making     1.0
# 555                   ok want sweet simple hard complex     1.0
# 556                                       making attack     1.0
# 557   complex basic pressure cooker bomb simple pipe...     1.0
# 558                      ok want cheap simple make bomb     1.0
# 559                                       journal entry     1.0
# 560                                  made list material     1.0
# 561                            course something contain     1.0
# 562   material world lie material world lie long tau...     1.0
# 563   vester flanagan shooting sure know day ago sho...     1.0
# 564   houston cop shooting read houston cop shooting...     1.0
# 565   wes craven dead age 76 august 30 2015 wes crav...     1.0
# 566   time long since time repent renaissance quaint...     1.0
# 567   weird scene disney movie great deal controvers...     1.0
# 568                      fun hamster everything amazing     1.0
# 569                                miscellaneous banter     1.0
# 570   noncolumbine spree movie favorite two bloody w...     1.0
# 571   noncolumbine spree movie probably one would li...     1.0
# 572   noncolumbine spree movie reaction wondering go...     1.0
# 573                    watching right obligated unleash     1.0
# 574   saw video several year ago began watching log ...     1.0
# 575                halloween thread used favorite movie     1.0
# 576                                      want see movie     1.0
# 577   vote considering posting topic sort indirectly...     1.0
# 578                  eating right water better flavored     1.0
# 579   agree nin would proud born random place sycoph...     1.0
# 580   twitter account school shooter save deletion a...     1.0
# 581   jared loughnertuscon massacre compared columbi...     1.0
# 582   boy band absence modern talking offend sensibi...     1.0
# 583   year shadow columbine book edit sorry see ls1s...     1.0
# 584   infinite gun consequence still waiting mass sh...     1.0
# 585   victim would dead people general receive respe...     1.0
# 586   bullying homophobia suicide see right fancy gr...     1.0
# 587                 body mod castrated 15 rebel society     1.0
# 588   postmortem disposal bodily remains seems like ...     1.0
# 589   ask permission loaded question requires think ...     1.0
# 590   thing change sure reformed government could so...     1.0
# 591   ask permission incidentally certain evaluation...     1.0
# 592   taking screenshot mac use iphone unless want s...     1.0
# 593   jared loughnertuscon massacre compared columbi...     1.0
# 594   virgin believe degenerate capitalistic system ...     1.0
# 595   jerry spring help america image much seems biz...     1.0
# 596   lifetime movie lauren townlands mother elisabe...     1.0
# 597   duck carbine high massacre anyone know sabbath...     1.0
# 598   eric dylan trial one major reason columbine st...     1.0
# 599   lifetime movie lauren townlands mother ultimat...     1.0
# 600                 dylan prom photo madonna done youth     1.0
# 601   lifetime movie lauren townlands mother stalkin...     1.0
# 602   time article basement tape basement tape must ...     1.0
# 603   excellent violate90s mass murderer documentary...     1.0
# 604   ever met exact opposite sex copy prospect one ...     1.0
# 605   china reportedly selling pill made dead baby s...     1.0
# 606   sleep naked someone decided pull boxer conting...     1.0
# 607   favorite holiday like holiday would say hallow...     1.0
# 608   matthew murray colorado shooting 07 robert haw...     1.0
# 609             visit littleton run klebold would point     1.0
# 610                          dylan live minute shooting     1.0
# 611   e breakfast club episode think talking involve...     1.0
# 612   full 911 call library youtube zerotolerance po...     1.0
# 613   full 911 call library mean literal sense elabo...     1.0
# 614   name meaning eric dylan one jared toughness vi...     1.0
# 615                                   could change word     1.0
# 616   moment restore faith humanity political ideolo...     1.0
# 617   moment restore faith humanity directed toward ...     1.0
# 618                           origin photo location may     1.0
# 619   house centipede awful might centipede house su...     1.0
# 620   couple image dylan never seen believe faked de...     1.0
# 621   couple image dylan never seen ridiculous accor...     1.0
# 622   moment restore faith humanity normally interes...     1.0
# 623   china reportedly selling pill made dead baby tuna     1.0
# 624            anyone facebook member ed vodka reb chat     1.0
# 625                virgin someone fetish property right     1.0
# 626   virgin underweight used think asexual primary ...     1.0
# 627   pumped kick hit song teenage killer found song...     1.0
# 628   watching right ago ellesieg posted link docume...     1.0
# 629       dunblane uk columbine dunblanes 11k 043149pdf     1.0
# 630   talking third shooter apparently ended fleeing...     1.0
# 631                               board dead ever alive     1.0
# 632   wonder dylan danced prom quote atleast columbi...     1.0
# 633   board dead regalis lucidity always guide u wor...     1.0
# 634   prank calling thegunsource thegunsource online...     1.0
# 635   dunblane uk columbine heard stranger scenario ...     1.0
# 636                       dunblane uk columbine 099path     1.0
# 637                              cell phone stick party     1.0
# 638   board dead madbomber three year still gone ram...     1.0
# 639   board dead uh oh behave aggressively coerce be...     1.0
# 640                        board dead thing cooperative     1.0
# 641                 gun gun got gun need flees 9 biceps     1.0
# 642   unanswerable question day imagine mother tryin...     1.0
# 643                     found hit list high school 3212     1.0
# 644   pumped kick hit song teenage killer oh dear wr...     1.0
# 645   gun kip linked used rifle two pistol spinoff r...     1.0
# 646   opinion eric dylan quote presumably made heypi...     1.0
# 647                                     kind puppy want     1.0
# 648   kind puppy want hamster pup infinitely superio...     1.0
# 649       kind puppy want sacrifice part satanic ritual     1.0
# 650      would shooting school murray got new madbomber     1.0
# 651   know people might like reality show looked bun...     1.0
# 652   know people might like reality show forgot wiz...     1.0
# 653   find forum think found google toward end 2006 ...     1.0
# 654   gun madbomber know think board dead troll arou...     1.0
# 655                     find forum talking kimveer gill     1.0
# 656   find forum yes quote people post directly eyec...     1.0
# 657   would shooting school r2267268 hope joking mis...     1.0
# 658   question make brain think little female genera...     1.0
# 659   question make brain think little depending def...     1.0
# 660   date death leave u hanging bro make sure uploa...     1.0
# 661   rip travis champ among hilarious thing seen li...     1.0
# 662                  unlocked secret columbine happened     1.0
# 663   origin name nixon tape think funny east asian ...     1.0
# 664   origin name nixon tape implying believe elepha...     1.0
# 665   bored yeah ballistic vest get heavy madbomberj...     1.0
# 666   really random question therapist secular pries...     1.0
# 667                                    rip travis champ     1.0
# 668                      drive anything car hater latin     1.0
# 669   hunting human whenever see title topic think j...     1.0
# 670   old bts released mean say seen tyler trolling ...     1.0
# 671   drive anything car abusethesoul wrote drive an...     1.0
# 672                                           listening     1.0
# 673   caused columbine one think goth resembles kimv...     1.0
# 674   listening oh yeah dj people splice together mu...     1.0
# 675                caused columbine being2jpg ebsitejpg     1.0
# 676      listening fine keep collection bare girl cover     1.0
# 677   21 year old friendless virgin right regain sti...     1.0
# 678   eric inspired watch trial eric eminent fancy l...     1.0
# 679             job maybe missed readilyavailable tec9s     1.0
# 680   jeff wise ignored happened indian reservation ...     1.0
# 681   dylan glass wearing glass might provoked eric ...     1.0
# 682                              superstitious remotely     1.0
# 683   superstitious going bother addressing know som...     1.0
# 684   forum crush say whatever wish know love regain...     1.0
# 685   dueling fangirls thread good work porter final...     1.0
# 686   rip travis champ think serendipitously came ac...     1.0
# 687   mao belong encouraged kid beat teacher meaning...     1.0
# 688   imagine different member board looking one gue...     1.0
# 689   thing make think columbine challenge porter101...     1.0
# 690                            unreleased cho manifesto     1.0
# 691                           gun outlaw gun outlaw gun     1.0
# 692   favorite film favorite difficult define sure k...     1.0
# 693   anyone dressing halloween never dress clothes ...     1.0
# 694   favorite film despite main champ orangutan won...     1.0
# 695   favorite film suppose attempted top 25 would e...     1.0
# 696   babyxenomorph wrote dest wrote london born bre...     1.0
# 697   11 yr old girl arrestedaccused making school t...     1.0
# 698   oatmealberry chipset cooky smigglestyle mix 3 ...     1.0
# 699   oatmealberry chipset cooky chair recognizes gu...     1.0
# 700   want die dying swordfight platypus would prett...     1.0
# 701                 want die platypus trivia 300aazthd7     1.0
# 702   jeff wise ivan wrote anyone heard michael ryan...     1.0
# 703   earliest movie portrayal massspree shooting kn...     1.0
# 704   earliest movie portrayal massspree shooting tr...     1.0
# 705             want die tyler trolling need topic made     1.0
# ...
# 2770       Threat Texts
# 2771       Threat Texts
# 2772       Threat Texts
# 2773       Threat Texts
# 2774       Threat Texts
# 2775       Threat Texts
# 2776       Threat Texts
# 2777       Threat Texts
# 2778       Threat Texts
# 2779       Threat Texts
# 2780       Threat Texts
# 2781       Threat Texts
# 2782       Threat Texts
# 2783       Threat Texts
# 2784       Threat Texts
# 2785       Threat Texts
# 2786       Threat Texts
# 2787       Threat Texts
# 2788       Threat Texts
# 2789       Threat Texts
# 2790       Threat Texts
# 2791       Threat Texts
# 2792       Threat Texts
# 2793       Threat Texts
# 2794       Threat Texts
# 2795       Threat Texts
# 2796       Threat Texts
# 2797       Threat Texts
# 2798       Threat Texts
# 2799       Threat Texts
# 2800       Threat Texts
# 2801       Threat Texts
# 2802       Threat Texts
# 2803       Threat Texts
# 2804       Threat Texts
# 2805       Threat Texts
# 2806       Threat Texts
# 2807       Threat Texts
# 2808       Threat Texts
# 2809       Threat Texts
# 2810       Threat Texts
# 2811       Threat Texts
# 2812       Threat Texts
# 2813       Threat Texts
# 2814       Threat Texts
# 2815       Threat Texts
# 2816       Threat Texts
# 2817       Threat Texts
# 2818       Threat Texts
# 2819       Threat Texts
# 2820       Threat Texts
# 2821       Threat Texts
# 2822       Threat Texts
# 2823       Threat Texts
# 2824       Threat Texts
# 2825       Threat Texts
# 2826       Threat Texts
# 2827       Threat Texts
# 2828       Threat Texts
# 2829       Threat Texts
# 2830       Threat Texts
# 2831       Threat Texts
# 2832       Threat Texts
# 2833       Threat Texts
# 2834       Threat Texts
# 2835       Threat Texts
# 2836       Threat Texts
# 2837       Threat Texts
# 2838       Threat Texts
# 2839       Threat Texts
# 2840       Threat Texts
# 2841       Threat Texts
# 2842       Threat Texts
# 2843       Threat Texts
# 2844       Threat Texts
# 2845       Threat Texts
# 2846       Threat Texts
# 2847       Threat Texts
# 2848       Threat Texts
# 2849       Threat Texts
# 2850       Threat Texts
# 2851       Threat Texts
# 2852       Threat Texts
# 2853       Threat Texts
# 2854       Threat Texts
# 2855       Threat Texts
# 2856       Threat Texts
# 2857       Threat Texts
# 2858       Threat Texts
# 2859       Threat Texts
# 2860       Threat Texts
# 2861       Threat Texts
# 2862       Threat Texts
# 2863       Threat Texts
# 2864       Threat Texts
# 2865       Threat Texts
# 2866       Threat Texts
# 2867       Threat Texts
# 2868       Threat Texts
# 2869       Threat Texts
# 2870       Threat Texts
# 2871       Threat Texts
# 2872       Threat Texts
# 2873       Threat Texts
# 2874       Threat Texts
# 2875       Threat Texts
# 2876       Threat Texts
# 2877       Threat Texts
# 2878       Threat Texts
# 2879       Threat Texts
# 2880       Threat Texts
# 2881       Threat Texts
# 2882       Threat Texts
# 2883       Threat Texts
# 2884       Threat Texts
# 2885       Threat Texts
# 2886       Threat Texts
# 2887       Threat Texts
# 2888       Threat Texts
# 2889       Threat Texts
# 2890       Threat Texts
# 2891       Threat Texts
# 2892       Threat Texts
# 2893       Threat Texts
# 2894       Threat Texts
# 2895       Threat Texts
# 2896       Threat Texts
# 2897       Threat Texts
# 2898       Threat Texts
# 2899       Threat Texts
# 2900       Threat Texts
# 2901       Threat Texts
# 2902       Threat Texts
# 2903       Threat Texts
# 2904       Threat Texts
# 2905       Threat Texts
# 2906       Threat Texts
# 2907       Threat Texts
# 2908       Threat Texts
# 2909       Threat Texts
# 2910       Threat Texts
# 2911       Threat Texts
# 2912       Threat Texts
# 2913       Threat Texts
# 2914       Threat Texts
# 2915       Threat Texts
# 2916       Threat Texts
# 2917       Threat Texts
# 2918       Threat Texts
# 2919       Threat Texts
# 2920       Threat Texts
# 2921       Threat Texts
# 2922       Threat Texts
# 2923       Threat Texts
# 2924       Threat Texts
# 2925       Threat Texts
# 2926       Threat Texts
# 2927       Threat Texts
# 2928       Threat Texts
# 2929       Threat Texts
# 2930       Threat Texts
# 2931       Threat Texts
# 2932       Threat Texts
# 2933       Threat Texts
# 2934       Threat Texts
# 2935       Threat Texts
# 2936       Threat Texts
# 2937       Threat Texts
# 2938       Threat Texts
# 2939       Threat Texts
# 2940       Threat Texts
# 2941       Threat Texts
# 2942       Threat Texts
# 2943       Threat Texts
# 2944       Threat Texts
# 2945       Threat Texts
# 2946       Threat Texts
# 2947       Threat Texts
# 2948       Threat Texts
# 2949       Threat Texts
# 2950       Threat Texts
# 2951       Threat Texts
# 2952       Threat Texts
# 2953       Threat Texts
# 2954       Threat Texts
# 2955       Threat Texts
# 2956       Threat Texts
# 2957       Threat Texts
# 2958       Threat Texts
# 2959       Threat Texts
# 2960       Threat Texts
# 2961       Threat Texts
# 2962       Threat Texts
# 2963       Threat Texts
# 2964       Threat Texts
# 2965       Threat Texts
# 2966       Threat Texts
# 2967       Threat Texts
# 2968       Threat Texts
# 2969       Threat Texts
# 2970       Threat Texts
# 2971       Threat Texts
# 2972       Threat Texts
# 2973       Threat Texts
# 2974       Threat Texts
# 2975       Threat Texts
# 2976       Threat Texts
# 2977       Threat Texts
# 2978       Threat Texts
# 2979       Threat Texts
# 2980       Threat Texts
# 2981       Threat Texts
# 2982       Threat Texts
# 2983       Threat Texts
# 2984       Threat Texts
# 2985       Threat Texts
# 2986       Threat Texts
# 2987       Threat Texts
# 2988       Threat Texts
# 2989       Threat Texts
# 2990       Threat Texts
# 2991       Threat Texts
# 2992       Threat Texts
# 2993       Threat Texts
# 2994       Threat Texts
# 2995       Threat Texts
# 2996       Threat Texts
# 2997       Threat Texts
# 2998       Threat Texts
# 2999       Threat Texts
# 3000       Threat Texts
# 3001       Threat Texts
# 3002       Threat Texts
# 3003       Threat Texts
# 3004       Threat Texts
# 3005       Threat Texts
# 3006       Threat Texts
# 3007       Threat Texts
# 3008       Threat Texts
# 3009       Threat Texts
# 3010       Threat Texts
# 3011       Threat Texts
# 3012       Threat Texts
# 3013       Threat Texts
# 3014       Threat Texts
# 3015       Threat Texts
# 3016       Threat Texts
# 3017       Threat Texts
# 3018       Threat Texts
# 3019       Threat Texts
# 3020       Threat Texts
# 3021       Threat Texts
# 3022       Threat Texts
# 3023       Threat Texts
# 3024       Threat Texts
# 3025       Threat Texts
# 3026       Threat Texts
# 3027       Threat Texts
# 3028       Threat Texts
# 3029       Threat Texts
# 3030       Threat Texts
# 3031       Threat Texts
# 3032       Threat Texts
# 3033       Threat Texts
# 3034       Threat Texts
# 3035       Threat Texts
# 3036       Threat Texts
# 3037       Threat Texts
# 3038       Threat Texts
# 3039       Threat Texts
# 3040       Threat Texts
# 3041       Threat Texts
# 3042       Threat Texts
# 3043       Threat Texts
# 3044       Threat Texts
# 3045       Threat Texts
# 3046       Threat Texts
# 3047       Threat Texts
# 3048       Threat Texts
# 3049       Threat Texts
# 3050       Threat Texts
# 3051       Threat Texts
# 3052       Threat Texts
# 3053       Threat Texts
# 3054       Threat Texts
# 3055       Threat Texts
# 3056       Threat Texts
# 3057       Threat Texts
# 3058       Threat Texts
# 3059       Threat Texts
# 3060       Threat Texts
# 3061       Threat Texts
# 3062       Threat Texts
# 3063       Threat Texts
# 3064       Threat Texts
# 3065       Threat Texts
# 3066       Threat Texts
# 3067       Threat Texts
# 3068       Threat Texts
# 3069       Threat Texts
# 3070       Threat Texts
# 3071       Threat Texts
# 3072       Threat Texts
# 3073       Threat Texts
# 3074       Threat Texts
# 3075       Threat Texts
# 3076       Threat Texts
# 3077       Threat Texts
# 3078       Threat Texts
# 3079       Threat Texts
# 3080       Threat Texts
# 3081       Threat Texts
# 3082       Threat Texts
# 3083       Threat Texts
# 3084       Threat Texts
# 3085       Threat Texts
# 3086       Threat Texts
# 3087       Threat Texts
# 3088       Threat Texts
# 3089       Threat Texts
# 3090       Threat Texts
# 3091       Threat Texts
# 3092       Threat Texts
# 3093       Threat Texts
# 3094       Threat Texts
# 3095       Threat Texts
# 3096       Threat Texts
# 3097       Threat Texts
# 3098       Threat Texts
# 3099       Threat Texts
# 3100       Threat Texts
# 3101       Threat Texts
# 3102       Threat Texts
# 3103       Threat Texts
# 3104       Threat Texts
# 3105       Threat Texts
# 3106       Threat Texts
# 3107       Threat Texts
# 3108       Threat Texts
# 3109       Threat Texts
# 3110       Threat Texts
# 3111       Threat Texts
# 3112       Threat Texts
# 3113       Threat Texts
# 3114       Threat Texts
# 3115       Threat Texts
# 3116       Threat Texts
# 3117       Threat Texts
# 3118       Threat Texts
# 3119       Threat Texts
# 3120       Threat Texts
